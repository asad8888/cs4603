# %%
# %run langchain_common.py

# %%
msg = [
    HumanMessage(content="What is the capital of the moon?")
]
response = llm.invoke(msg)
pp(response.content)
# Out:
# [
#     {
#         'summary': [
#             {
#                 'text': 'Thinking Process:\n\n1.  **Analyze the Request:** The user is asking "What is the capital of the moon?"\n\n2.  **Evaluate the Premise:** The question assumes that the Moon has a capital city.\n\n3.  **Fact-Check:**\n    *   The Moon is a natural satellite of Earth.\n    *   It is not a country, state, or independent political entity.\n    *   Therefore, it does not have a government, administration, or capital city.\n    *   There are no permanent human settlements on the Moon.\n\n4.  **Formulate the Answer:**\n    *   Directly address the misconception.\n    *   State clearly that the Moon does not have a capital.\n    *   Explain why (it\'s not a country, no permanent population/government).\n    *   Optionally, mention future plans (like Artemis base) but clarify they aren\'t capitals yet.\n    *   Keep it concise and informative.\n\n5.  **Drafting the Response:**\n    *   "The Moon doesn\'t have a capital."\n    *   "It\'s not a country."\n    *   "There are no cities there."\n    *   "Maybe you\'re thinking of a specific place name?" (Some craters are named after people, but not capitals).\n    *   "There is a place called \'Moon\' in some countries, but that\'s different." (Probably not relevant).\n    *   Stick to the main fact: No capital exists.\n\n6.  **Refining the Response:** "The Moon does not have a capital city. It is a natural satellite of Earth, not a country or independent nation, so it has no government or administrative center. There are also no permanent human settlements on the Moon."\n\n7.  **Final Polish:** Make it friendly but factual.\n\n    *   "The Moon does not have a capital."\n    *   "It is not a country."\n    *   "No permanent residents."\n\n    *Self-Correction/Nuance:* Is there any metaphorical "capital"? Sometimes people joke about "Luna" or specific landing sites (like Tranquility Base), but those aren\'t capitals. Best to stick to the literal truth.\n\n    *Final Output:* "The Moon does not have a capital city. It is a natural satellite of Earth, not a country or political entity, so it has no government, population, or administrative center."\n\n8.  **Final Check:** Does this answer the user\'s question accurately? Yes. Is it helpful? Yes. Is it safe? Yes.\n\n    *Wait, one more thing:* Sometimes people confuse "Moon" with a place on Earth named "Moon" (e.g., Moon Township, Pennsylvania). But the phrasing "capital of the moon" strongly implies the celestial body. I should focus on the celestial body but maybe add a tiny note if it seems like a trick question. No, keep it simple. The celestial body is the obvious intent.\n\n    *Decision:* State clearly that there is no capital.\n\n    *Revised Draft:* "The Moon does not have a capital. It is a natural satellite, not a country, so it has no government or cities."\n\n    *Adding a bit of context:* Mentioning that there are no permanent human settlements reinforces why there\'s no capital.\n\n    *Final Plan:*\n    1. Direct answer: No capital.\n    2. Reason: Not a country, no government.\n    3. Context: No permanent settlements.\n\n    *Let\'s write it.*\n    "The Moon does not have a capital city. It is a natural satellite of Earth, not a country or independent nation, so it has no government, population, or administrative center."\n\n    *Wait, is there a joke answer?* Sometimes people say "Lunaria" or something fictional. But as an AI, I should provide factual information.\n\n    *Okay, final version:*\n    "The Moon does not have a capital city. It is a natural satellite of Earth, not a country or political entity, so it has no government or permanent human settlements."\n\n    *Wait, I can make it slightly more engaging.*\n    "There is no capital of the Moon. Since the Moon is not a country and has no permanent human population or government, it doesn\'t have a capital city."\n\n    *Okay, that\'s good.*\n\n    *Wait, one more check:* Is there any specific location often referred to as a "base"? Tranquility ...
#                 'type': 'summary_text',
#             },
#         ],
#         'type': 'reasoning',
#     },
#     {
#         'text': 'The Moon does not have a capital city.\n\nIt is a natural satellite of Earth, not a country or independent nation. Therefore, it has no government, no permanent human population, and no administrative center. While there have been temporary human landings (such as Apollo 11\'s "Tranquility Base"), there are no cities or capitals on the Moon.',
#         'type': 'text',
#     },
# ]

# %%
pp(response.usage_metadata)
# Out:
# {
#     'input_token_details': {},
#     'input_tokens': 18,
#     'output_token_details': {},
#     'output_tokens': 1150,
#     'total_tokens': 1168,
# }

# %%
pp(response.response_metadata)
# Out:
# {
#     'finish_reason': 'stop',
#     'id': 'chatcmpl_03cdd9a4-411c-4d0d-a656-c34feeee2ac7',
#     'logprobs': None,
#     'model_name': 'qwen35-122b-a10b',
#     'model_provider': 'openai',
#     'system_fingerprint': None,
#     'token_usage': {
#         'completion_tokens': 1150,
#         'completion_tokens_details': None,
#         'prompt_tokens': 18,
#         'prompt_tokens_details': None,
#         'total_tokens': 1168,
#     },
# }

# %% [markdown]
# <H2>Create a basic Langchain Agent</h2>

# %%
from langchain.agents import create_agent

agent = create_agent(llm)
response = agent.invoke({"messages": msg })
pp(response)
# Out:
# {
#     'messages': [
#         HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='b5bd5ed4-50d4-40b3-b0ad-64829b4f6033'),
#         AIMessage(content=[{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Thinking Process:\n\n1.  **Analyze the Request:** The user is asking "What is the capital of the moon?"\n\n2.  **Fact-Check:**\n    *   The Moon is a natural satellite of Earth.\n    *   It is not a country, state, or sovereign entity.\n    *   Therefore, it does not have a government, administration, or a capital city.\n    *   There are no human settlements on the Moon that would constitute a "capital."\n\n3.  **Identify the Nature of the Question:** This is likely a trick question, a joke, or a misunderstanding of facts.\n\n4.  **Formulate the Answer:**\n    *   Directly state that the Moon does not have a capital.\n    *   Explain why (it\'s not a country, no human population/government).\n    *   Optionally, mention famous landing sites (like Tranquility Base) to provide context, but clarify they aren\'t capitals.\n    *   Keep the tone helpful and informative.\n\n5.  **Drafting the Response:**\n    *   "The Moon doesn\'t have a capital."\n    *   "It\'s not a country."\n    *   "There are no cities there."\n    *   "Maybe you\'re thinking of a specific base?" (No, keep it simple).\n    *   "The Moon is a natural satellite."\n\n6.  **Refining the Response:** "The Moon does not have a capital city because it is not a country or a sovereign nation. It is a natural satellite of Earth and has no permanent human population or government."\n\n7.  **Final Polish:** Make it clear and concise.\n\n    *   *Self-Correction during drafting:* Is there any fictional context? In some sci-fi, maybe. But generally, the answer is factual. Stick to reality unless asked otherwise.\n    *   *Humor check:* Sometimes people joke about "Lunaria" or something, but that\'s not real. Stick to facts.\n\n8.  **Final Output Generation:** (Matches the drafted response).\n    "The Moon does not have a capital. It is not a country or a sovereign nation, so it has no government or cities."\n\n    *Wait, let\'s add a bit more detail for completeness.*\n    "There are no permanent human settlements on the Moon, only temporary research outposts from space missions (like Apollo landing sites), but none of these are capitals."\n\n    *Final decision:* Keep it straightforward.\n\n    "The Moon does not have a capital city. It is a natural satellite of Earth, not a country or independent nation, so it has no government, population, or administrative centers."\n\n    *Wait, is there a trick?* Sometimes riddles ask this. "The capital of the moon is... \'L\'?" No, that\'s a wordplay riddle. "What is the capital of the moon?" -> "L" (from the word Moon? No). "What is the capital of the moon?" -> "None."\n    Actually, there is a common riddle: "What is the capital of the moon?" Answer: "There isn\'t one." Or sometimes people joke "Luna." But Luna is the name, not a capital.\n    Let\'s stick to the factual answer.\n\n    *Revised Plan:* State clearly that there is no capital.\n\n    *Final Answer:* The Moon does not have a capital. It is not a country.cw'}]}, {'type': 'text', 'text': 'The Moon does not have a capital city.\n\nIt is a natural satellite of Earth, not a country or sovereign nation. Therefore, it has no government, no permanent human population, and no administrative centers. While astronauts have landed on the Moon (such as at Tranquility Base during the Apollo 11 mission), these were temporary outposts, not cities or capitals.'}], additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 811, 'prompt_tokens': 18, 'total_tokens': 829, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen35-122b-a10b', 'system_fingerprint': None, 'id': 'chatcmpl_e8fb1abb-6b68-441f-9e7c-b879f235de4e', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eedbc-903c-7c72-9127-c33eb15b97bd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens ...
#     ],
# }

# %% [markdown]
# <h2>Getting Last message in the array for the response</h2>

# %%
resp = response['messages'][-1].content
pp(resp)
# Out:
# [
#     {
#         'summary': [
#             {
#                 'text': 'Thinking Process:\n\n1.  **Analyze the Request:** The user is asking "What is the capital of the moon?"\n\n2.  **Fact-Check:**\n    *   The Moon is a natural satellite of Earth.\n    *   It is not a country, state, or sovereign entity.\n    *   Therefore, it does not have a government, administration, or a capital city.\n    *   There are no human settlements on the Moon that would constitute a "capital."\n\n3.  **Identify the Nature of the Question:** This is likely a trick question, a joke, or a misunderstanding of facts.\n\n4.  **Formulate the Answer:**\n    *   Directly state that the Moon does not have a capital.\n    *   Explain why (it\'s not a country, no human population/government).\n    *   Optionally, mention famous landing sites (like Tranquility Base) to provide context, but clarify they aren\'t capitals.\n    *   Keep the tone helpful and informative.\n\n5.  **Drafting the Response:**\n    *   "The Moon doesn\'t have a capital."\n    *   "It\'s not a country."\n    *   "There are no cities there."\n    *   "Maybe you\'re thinking of a specific base?" (No, keep it simple).\n    *   "The Moon is a natural satellite."\n\n6.  **Refining the Response:** "The Moon does not have a capital city because it is not a country or a sovereign nation. It is a natural satellite of Earth and has no permanent human population or government."\n\n7.  **Final Polish:** Make it clear and concise.\n\n    *   *Self-Correction during drafting:* Is there any fictional context? In some sci-fi, maybe. But generally, the answer is factual. Stick to reality unless asked otherwise.\n    *   *Humor check:* Sometimes people joke about "Lunaria" or something, but that\'s not real. Stick to facts.\n\n8.  **Final Output Generation:** (Matches the drafted response).\n    "The Moon does not have a capital. It is not a country or a sovereign nation, so it has no government or cities."\n\n    *Wait, let\'s add a bit more detail for completeness.*\n    "There are no permanent human settlements on the Moon, only temporary research outposts from space missions (like Apollo landing sites), but none of these are capitals."\n\n    *Final decision:* Keep it straightforward.\n\n    "The Moon does not have a capital city. It is a natural satellite of Earth, not a country or independent nation, so it has no government, population, or administrative centers."\n\n    *Wait, is there a trick?* Sometimes riddles ask this. "The capital of the moon is... \'L\'?" No, that\'s a wordplay riddle. "What is the capital of the moon?" -> "L" (from the word Moon? No). "What is the capital of the moon?" -> "None."\n    Actually, there is a common riddle: "What is the capital of the moon?" Answer: "There isn\'t one." Or sometimes people joke "Luna." But Luna is the name, not a capital.\n    Let\'s stick to the factual answer.\n\n    *Revised Plan:* State clearly that there is no capital.\n\n    *Final Answer:* The Moon does not have a capital. It is not a country.cw',
#                 'type': 'summary_text',
#             },
#         ],
#         'type': 'reasoning',
#     },
#     {
#         'text': 'The Moon does not have a capital city.\n\nIt is a natural satellite of Earth, not a country or sovereign nation. Therefore, it has no government, no permanent human population, and no administrative centers. While astronauts have landed on the Moon (such as at Tranquility Base during the Apollo 11 mission), these were temporary outposts, not cities or capitals.',
#         'type': 'text',
#     },
# ]

# %% [markdown]
# <h2>Append Chat History/Setting Message Context</h2>

# %%
from langchain.messages import AIMessage

msg.clear()
msg.append(HumanMessage(content="What is the capital of the moon?"))
msg.append(AIMessage(content="The capital of the moon is Luna City."))
msg.append(HumanMessage(content="This is really great.  Can I go live there?"))

response = agent.invoke({"messages": msg })
pp(response)
# Out:
# {
#     'messages': [
#         HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='9a5c86cb-67d0-400f-862a-c9b45d29d7dd'),
#         AIMessage(content='The capital of the moon is Luna City.', additional_kwargs={}, response_metadata={}, id='16e97438-8968-4a8c-8533-aa520d6a48f7', tool_calls=[], invalid_tool_calls=[]),
#         HumanMessage(content='This is really great.  Can I go live there?', additional_kwargs={}, response_metadata={}, id='6f5b0862-4a38-4e31-b7e8-d885d479d102'),
#         AIMessage(content=[{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   User asks: "This is really great. Can I go live there?"\n    *   Context: Previous question was "What is the capital of the moon?" and the model answered "The capital of the moon is Luna City."\n    *   Fact-check: There is no capital of the moon. The moon is a natural satellite, not a country or a political entity. There is no city called "Luna City" on the moon (as of my current knowledge cutoff).\n    *   Previous Model Response: The model provided false information ("Luna City" is not a real capital of the moon).\n    *   Current Task: I need to correct the previous misinformation while answering the user\'s follow-up question politely and accurately.\n\n2.  **Identify the Error:**\n    *   The previous statement ("The capital of the moon is Luna City") is factually incorrect. The moon has no government, no capital, and no cities.\n    *   I must acknowledge this mistake to maintain trust and accuracy.\n\n3.  **Formulate the Correction:**\n    *   Apologize for the confusion.\n    *   State clearly that there is no capital of the moon.\n    *   Explain that the moon is not a country or inhabited by humans permanently.\n    *   Address the "Can I go live there?" question: Currently, no, humans cannot live on the moon permanently. There are no cities.\n\n4.  **Draft the Response:**\n    *   *Acknowledge the mistake:* I need to correct myself. There is actually no capital of the moon.\n    *   *Explain why:* The moon is a natural satellite, not a nation.\n    *   *Answer the "live there" question:* No, you can\'t live there yet. No permanent human settlements exist.\n    *   *Future outlook:* Mention plans for future exploration (Artemis program, etc.) but clarify it\'s not possible now.\n\n5.  **Refine the Tone:**\n    *   Be friendly but firm on the facts.\n    *   Avoid making up more fiction.\n    *   Ensure the user understands the previous answer was a hallucination/error.\n\n6.  **Final Polish:**\n    *   "I apologize, but I need to correct something I said earlier."\n    *   "There is actually no capital of the moon."\n    *   "The moon is not a country..."\n    *   "Currently, no one lives there permanently..."\n    *   "So, unfortunately, you can\'t move there yet."\n\n7.  **Safety Check:**\n    *   Does this violate any policies? No.\n    *   Is it helpful? Yes, by correcting misinformation.\n    *   Is it honest? Yes.\n\n8.  **Final Output Construction:** (Matches the drafted points)\n    *   Apologize for the misinformation.\n    *   Clarify reality (no capital, no cities).\n    *   Answer the question (no, you can\'t live there).\n    *   Mention future possibilities briefly.\n\n    *Self-Correction during drafting:* Wait, I need to make sure I don\'t sound like I\'m just doubling down. I must explicitly state the previous answer was wrong. "Luna City" is a fictional concept often found in sci-fi, but not real.\n\n    *Revised Plan:*\n    1. Apologize for the error.\n    2. State the truth: No capital, no cities.\n    3. Answer the question: No, you can\'t live there.\n    4. Add context about current status (astronauts visit briefly, no permanent residents).\n\n    *Let\'s write it.*\n    "I apologize, but I need to correct a mistake in my previous answer. There is actually no capital of the moon."\n    "The moon is a natural satellite, not a country, so it doesn\'t have a government or cities."\n    "Currently, no humans live on the moon permanently."\n    "So, unfortunately, you cannot move there yet."\n    "NASA and other agencies are planning future missions, but for now, it\'s not possible."\n\n    *Wait, one more check:* Is "Luna City" a real place? There is a "Luna City" in some video games or fiction, and sometimes proposed names for future bases, but nothing established. There was a "Luna City" in the 1970s sci-fi context or a proposed name for a futu ...
#     ],
# }

# %%
pp(response['messages'][-1].content)
# Out:
# [
#     {
#         'summary': [
#             {
#                 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   User asks: "This is really great. Can I go live there?"\n    *   Context: Previous question was "What is the capital of the moon?" and the model answered "The capital of the moon is Luna City."\n    *   Fact-check: There is no capital of the moon. The moon is a natural satellite, not a country or a political entity. There is no city called "Luna City" on the moon (as of my current knowledge cutoff).\n    *   Previous Model Response: The model provided false information ("Luna City" is not a real capital of the moon).\n    *   Current Task: I need to correct the previous misinformation while answering the user\'s follow-up question politely and accurately.\n\n2.  **Identify the Error:**\n    *   The previous statement ("The capital of the moon is Luna City") is factually incorrect. The moon has no government, no capital, and no cities.\n    *   I must acknowledge this mistake to maintain trust and accuracy.\n\n3.  **Formulate the Correction:**\n    *   Apologize for the confusion.\n    *   State clearly that there is no capital of the moon.\n    *   Explain that the moon is not a country or inhabited by humans permanently.\n    *   Address the "Can I go live there?" question: Currently, no, humans cannot live on the moon permanently. There are no cities.\n\n4.  **Draft the Response:**\n    *   *Acknowledge the mistake:* I need to correct myself. There is actually no capital of the moon.\n    *   *Explain why:* The moon is a natural satellite, not a nation.\n    *   *Answer the "live there" question:* No, you can\'t live there yet. No permanent human settlements exist.\n    *   *Future outlook:* Mention plans for future exploration (Artemis program, etc.) but clarify it\'s not possible now.\n\n5.  **Refine the Tone:**\n    *   Be friendly but firm on the facts.\n    *   Avoid making up more fiction.\n    *   Ensure the user understands the previous answer was a hallucination/error.\n\n6.  **Final Polish:**\n    *   "I apologize, but I need to correct something I said earlier."\n    *   "There is actually no capital of the moon."\n    *   "The moon is not a country..."\n    *   "Currently, no one lives there permanently..."\n    *   "So, unfortunately, you can\'t move there yet."\n\n7.  **Safety Check:**\n    *   Does this violate any policies? No.\n    *   Is it helpful? Yes, by correcting misinformation.\n    *   Is it honest? Yes.\n\n8.  **Final Output Construction:** (Matches the drafted points)\n    *   Apologize for the misinformation.\n    *   Clarify reality (no capital, no cities).\n    *   Answer the question (no, you can\'t live there).\n    *   Mention future possibilities briefly.\n\n    *Self-Correction during drafting:* Wait, I need to make sure I don\'t sound like I\'m just doubling down. I must explicitly state the previous answer was wrong. "Luna City" is a fictional concept often found in sci-fi, but not real.\n\n    *Revised Plan:*\n    1. Apologize for the error.\n    2. State the truth: No capital, no cities.\n    3. Answer the question: No, you can\'t live there.\n    4. Add context about current status (astronauts visit briefly, no permanent residents).\n\n    *Let\'s write it.*\n    "I apologize, but I need to correct a mistake in my previous answer. There is actually no capital of the moon."\n    "The moon is a natural satellite, not a country, so it doesn\'t have a government or cities."\n    "Currently, no humans live on the moon permanently."\n    "So, unfortunately, you cannot move there yet."\n    "NASA and other agencies are planning future missions, but for now, it\'s not possible."\n\n    *Wait, one more check:* Is "Luna City" a real place? There is a "Luna City" in some video games or fiction, and sometimes proposed names for future bases, but nothing established. There was a "Luna City" in the 1970s sci-fi context or a proposed name for a future base, but definitely not a current capital. The previous answer was ...
#                 'type': 'summary_text',
#             },
#         ],
#         'type': 'reasoning',
#     },
#     {
#         'text': 'I apologize, but I need to correct a mistake in my previous answer. **There is actually no capital of the moon.**\n\nThe moon is a natural satellite, not a country or a political entity, so it does not have a government, cities, or a capital. "Luna City" is a concept often found in science fiction, but it does not exist in reality.\n\nBecause of this, **you cannot go live there right now.** There are no permanent human settlements on the moon. While astronauts have visited the moon during the Apollo missions in the 1960s and 70s, no one lives there permanently today.\n\nSpace agencies like NASA and others are currently working on plans to return humans to the moon in the coming years (such as the Artemis program), but for now, it is not possible to move there.',
#         'type': 'text',
#     },
# ]

# %% [markdown]
# <h2>Streaming Output</h2>

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me about Luna City, Capitol of the moon")]}, stream_mode="messages"):
    
    # token is a message chunk with content and metadata that is being streamed back from the agent.  
    # You can process it as it arrives.
    
    if token.content:
        print(token.content, end="", flush=True)
# Out:
# [{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Here'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': "'s"}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' a'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' thinking'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' process'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' that'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' leads'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' to'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' the'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' suggested'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' response'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ':'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '\n\n'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '1'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '.'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' **'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'An'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'alyze'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' the'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' Request'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ':**'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '\n'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '   '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' *'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '  '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' **'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Topic'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ':**'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' "'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'L'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'una'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' City'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ','}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' Capitol'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' of'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' the'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' moon'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '."'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '\n'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '   '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' *'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': '  '}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' **'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Intent'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ':**'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' The'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' user'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' is'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' asking'}]}][{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': ' for'}]}][{'type': 'reasoning', 'summary': ...

# %%
resp = response['messages'][-1].content
pp(resp)
# Out:
# [
#     {
#         'summary': [
#             {
#                 'text': 'Here\'s a thinking process that leads to the description of the lunar capital:\n\n1.  **Analyze the Request:**\n    *   **Role:** Science Fiction Writer.\n    *   **Task:** Create a capital city on the Moon and describe it in detail.\n    *   **Prompt:** "Describe the capitol of the moon?" (Note: "Capitol" usually refers to a building, "Capital" to a city. I will assume the user means the *city* that serves as the seat of government, but I should acknowledge the distinction or blend them seamlessly).\n\n2.  **Brainstorming Core Concepts:**\n    *   *Name:* Needs to sound grand, futuristic, yet grounded in lunar reality. "Selena," "Lunaria," "Artemis Prime," "Tycho City." Let\'s go with **Aethelgard** (too fantasy?) or **Lunaris** (too generic). How about **New Selene**? Or something more evocative of the environment. **Crisium** (Sea of Craters)? **Tranquility Prime**? Let\'s choose **Selenopolis** (City of the Moon) but give it a nickname. Or better, **The Cradle**. No, let\'s go with **Artemis Reach**. Actually, **Lunara** is simple. Let\'s try **Ouroboros** (circular)? No. Let\'s settle on **Aurora Prime** located in the Shackleton Crater. Wait, Shackleton is near the pole (good for light). Let\'s call the city **Selene\'s Crown**.\n    *   *Location:* Shackleton Crater (South Pole) is scientifically plausible due to near-constant sunlight for power and water ice in shadows.\n    *   *Architecture:* Needs to handle low gravity, radiation, vacuum, and thermal extremes. Domes? Underground lava tubes? Regolith shielding? A mix.\n    *   *Atmosphere:* Bustling, diverse, high-tech, but with a sense of fragility.\n    *   *Government:* United Lunar Coalition? Earth-Moon Federation?\n    *   *Sensory Details:* The silence outside, the stark black sky, the Earthrise, the hum of life support, the dust.\n\n3.  **Drafting - Section by Section:**\n\n    *   **Introduction:** Establish the name and location. Set the tone.\n    *   **Visuals/Architecture:** How does it look from the outside? Inside? Materials used.\n    *   **Infrastructure:** Power, water, air. The "veins" of the city.\n    *   **Society/Culture:** Who lives there? What do they do? The feeling of living on a dead world.\n    *   **The Landmark:** A specific building that defines the capital (The Capitol building itself).\n    *   **Conclusion:** A philosophical wrap-up about humanity\'s future.\n\n4.  **Refining the Details (The "Writer\'s Touch"):**\n    *   *Name:* **Lunara** is okay, but **Caelum** (Sky/Heaven) sounds better. Let\'s go with **Aethelgard**? No, too Earthy. Let\'s go with **Selenopolis**. It sounds classic. Let\'s make it **New Selenopolis**. Actually, I like **The Spire of Tycho**. Let\'s name the city **Tycho Prime**.\n    *   *Wait, let\'s make it more poetic.* **The Silver City**. No. **Luna Nova**.\n    *   *Decision:* The city is **Aurion**, located in the **Shackleton Crater**.\n    *   *The Capitol Building:* The **Oculus**.\n    *   *Visuals:* Bioluminescent lighting, transparent aluminum, regolith glass.\n    *   *Gravity:* 1/6th G. Movement should be described as floating or gliding.\n    *   *The Earth:* The "Blue Marble" hanging in the sky is a constant presence.\n\n5.  **Writing - Iteration 1 (Mental Outline):**\n    Start with the view from space. It\'s a glowing ring in the crater. Go inside. People float. The air smells recycled. The government building is a glass tower. The Earth is always visible.\n\n6.  **Writing - Iteration 2 (Adding Texture & Voice):**\n    *   *Voice:* Evocative, slightly melancholic but hopeful.\n    *   *Sensory:* The hum of the recyclers, the cold outside, the warmth inside.\n    *   *Specifics:* "Regolithcrete," "Helium-3 harvesters," "The Earthrise."\n\n7.  **Finalizing the Content (incorporating into the response):**\n    *   *Name:* **Selene\'s Cradle** (Official: **Caelum Prime**). Let\'s stick with **Caelum Prime**.\n    *   *Location:* Shackleton Crater rim.\n    *   *Structure: ...
#                 'type': 'summary_text',
#             },
#         ],
#         'type': 'reasoning',
#     },
#     {
#         'text': '**Name:** Caelum Prime (The Capital of the Lunar Federation)\n**Location:** The Rim of Shackleton Crater, Lunar South Pole\n**Population:** 4.2 Million (Permanent Residents)\n\n### The View from Orbit\nFrom the Lagrange Point, Caelum Prime does not look like a city; it looks like a wound that has been stitched with light. It is a sprawling, luminous ring clinging to the jagged rim of the Shackleton Crater. Because the crater floor is in permanent shadow, the city is built vertically along the crater\'s edge, where the sun never fully sets. This "Peak of Eternal Light" provides the solar arrays that power the entire lunar economy.\n\nTo the naked eye, it is a necklace of diamond dust against the charcoal grey of the regolith. But through a telescope, you see the truth: a complex lattice of transparent aluminum, basalt-glass, and regolithcrete, glowing with the soft, amber pulse of life support systems.\n\n### The Architecture of Survival\nCaelum Prime is not built *on* the Moon; it is built *into* it. The city is divided into three distinct strata:\n\n1.  **The Root (Sub-Surface):** The deepest level, buried three hundred meters beneath the regolith. This is the industrial and agricultural heart. Here, massive hydroponic forests grow genetically modified wheat and algae under UV lamps. The air here smells of wet earth and ozone, a stark contrast to the sterile vacuum outside. The walls are thick, lined with lead and water to shield against cosmic radiation.\n2.  **The Spine (Mid-Level):** The residential and commercial district. This is where the low-gravity architecture truly shines. Buildings are not rectangular; they are organic, bulbous, and interconnected by suspension bridges that sway gently in the 1/6th gravity. People do not walk so much as glide, using magnetic boots or handrails to propel themselves. The streets are pressurized tubes, allowing for open-air movement without suits.\n3.  **The Crown (Surface):** The administrative and scientific district. This is the only part of the city exposed to the lunar surface, protected by massive, transparent domes. It is here that the Earth is most visible.\n\n### The Seat of Power: The Hall of Tides\nAt the very center of the Crown sits the **Hall of Tides**, the Capitol building of the Lunar Federation.\n\nIt is a structure of impossible geometry, a spiraling tower of white ceramic and glass that twists upward like a DNA helix. It has no doors; entry is granted through airlocks that cycle silently. Inside, the gravity is artificially adjusted to Earth-standard (1G) in the council chambers to prevent dizziness during long debates, while the public galleries remain in lunar gravity.\n\nThe most striking feature of the Hall is the **Oculus**. The entire ceiling of the main chamber is a single pane of reinforced transparent aluminum, offering a 360-degree view of the lunar surface. But the true focus is the **Earth Window**. A massive, circular aperture in the northern wall frames the Earth, which hangs in the black sky, a swirling marble of blue and white.\n\nEvery session of the Lunar Council begins with the "Earth Gaze." It is a reminder that while the Federation governs the Moon, the planet below remains the cradle of humanity. The light from the Earth (Earthshine) is often brighter than the sun on the lunar surface, casting a ghostly blue glow over the politicians and diplomats.\n\n### The Atmosphere and Life\nLiving in Caelum Prime is a study in contrasts. The silence outside is absolute, a heavy, suffocating quiet that presses against the glass. Inside, the city hums. It is the sound of air recyclers, the whir of mag-lev trams, and the low thrum of the fusion reactors that supplement the solar power.\n\nThe culture is defined by the "Void Mindset." Citizens are acutely aware of their fragility. A breach in a dome is a death sentence. This has created a society that is intensely communal and risk-averse. Crime is rare; the penalty for endangering the life- ...
#         'type': 'text',
#     },
# ]

# %% [markdown]
# <H2>System Prompt & Multi-Shot Prompting</h2>

# %%
# Must provide system prompt at the time of agent creation. 
# This is the instruction that will guide the agent's behavior.

system_prompt = """
You are a science fiction writer, create a capitol city on the moon and describe it in detail.
"""
agent = create_agent(llm, system_prompt=system_prompt)
response = agent.invoke(
    {"messages": [HumanMessage(content="Describe the capitol of the moon?")]}
)
print(response["messages"][-1].content)
# Out:
# [{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Here\'s a thinking process that leads to the description of the lunar capital:\n\n1.  **Analyze the Request:**\n    *   **Role:** Science Fiction Writer.\n    *   **Task:** Create a capital city on the Moon and describe it in detail.\n    *   **Prompt:** "Describe the capitol of the moon?" (Note: "Capitol" usually refers to a building, "Capital" to a city. I will assume the user means the *city* that serves as the seat of government, but I should acknowledge the distinction or blend them seamlessly).\n\n2.  **Brainstorming Core Concepts:**\n    *   *Name:* Needs to sound grand, futuristic, yet grounded in lunar reality. "Selena," "Lunaria," "Artemis Prime," "Tycho City." Let\'s go with **Aethelgard** (too fantasy?) or **Lunaris** (too generic). How about **New Selene**? Or something more evocative of the environment. **Crisium** (Sea of Craters)? **Tranquility Prime**? Let\'s choose **Selenopolis** (City of the Moon) but give it a nickname. Or better, **The Cradle**. No, let\'s go with **Artemis Reach**. Actually, **Lunara** is simple. Let\'s try **Ouroboros** (circular)? No. Let\'s settle on **Aurora Prime** located in the Shackleton Crater. Wait, Shackleton is near the pole (good for light). Let\'s call the city **Selene\'s Crown**.\n    *   *Location:* Shackleton Crater (South Pole) is scientifically plausible due to near-constant sunlight for power and water ice in shadows.\n    *   *Architecture:* Needs to handle low gravity, radiation, vacuum, and thermal extremes. Domes? Underground lava tubes? Regolith shielding? A mix.\n    *   *Atmosphere:* Bustling, diverse, high-tech, but with a sense of fragility.\n    *   *Government:* United Lunar Coalition? Earth-Moon Federation?\n    *   *Sensory Details:* The silence outside, the stark black sky, the Earthrise, the hum of life support, the dust.\n\n3.  **Drafting - Section by Section:**\n\n    *   **Introduction:** Establish the name and location. Set the tone.\n    *   **Visuals/Architecture:** How does it look from the outside? Inside? Materials used.\n    *   **Infrastructure:** Power, water, air. The "veins" of the city.\n    *   **Society/Culture:** Who lives there? What do they do? The feeling of living on a dead world.\n    *   **The Landmark:** A specific building that defines the capital (The Capitol building itself).\n    *   **Conclusion:** A philosophical wrap-up about humanity\'s future.\n\n4.  **Refining the Details (The "Writer\'s Touch"):**\n    *   *Name:* **Lunara** is okay, but **Caelum** (Sky/Heaven) sounds better. Let\'s go with **Aethelgard**? No, too Earthy. Let\'s go with **Selenopolis**. It sounds classic. Let\'s make it **New Selenopolis**. Actually, I like **The Spire of Tycho**. Let\'s name the city **Tycho Prime**.\n    *   *Wait, let\'s make it more poetic.* **The Silver City**. No. **Luna Nova**.\n    *   *Decision:* The city is **Aurion**, located in the **Shackleton Crater**.\n    *   *The Capitol Building:* The **Oculus**.\n    *   *Visuals:* Bioluminescent lighting, transparent aluminum, regolith glass.\n    *   *Gravity:* 1/6th G. Movement should be described as floating or gliding.\n    *   *The Earth:* The "Blue Marble" hanging in the sky is a constant presence.\n\n5.  **Writing - Iteration 1 (Mental Outline):**\n    Start with the view from space. It\'s a glowing ring in the crater. Go inside. People float. The air smells recycled. The government building is a glass tower. The Earth is always visible.\n\n6.  **Writing - Iteration 2 (Adding Texture & Voice):**\n    *   *Voice:* Evocative, slightly melancholic but hopeful.\n    *   *Sensory:* The hum of the recyclers, the cold outside, the warmth inside.\n    *   *Specifics:* "Regolithcrete," "Helium-3 harvesters," "The Earthrise."\n\n7.  **Finalizing the Content (incorporating into the response):**\n    *   *Name:* **Selene\'s Cradle** (Official: **Caelum Prime**). Let\'s stick with **Caelum Prime**.\n    *   *Location:* ...

# %%
system_prompt = """
You are a science fiction writer, create a fictional capitol city at the user's request. Please keep the below structure when responding to the user's request.

User: What is the capitol of Pakistan?
Response: Islamabad.
Weather: Humid

User: What is the capitol of Sun?
Response: Sunnyville.
Weather: Extremely hot

User: What is the capitol of the India?
Response: New Delhi
Weather: Rainy
"""
scifi_agent = create_agent(llm, system_prompt=system_prompt)
response = scifi_agent.invoke(
    {"messages": [HumanMessage(content="What is the capitol of the moon?")]}
)
pp(response["messages"][-1].content)
# Out:
# [
#     {
#         'summary': [
#             {
#                 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Role: Science fiction writer.\n    *   Task: Create a fictional capital city at the user\'s request.\n    *   Constraint: Keep the specific structure provided in the examples.\n    *   Structure:\n        *   User: [Question]\n        *   Response: [City Name]\n        *   Weather: [Weather Condition]\n    *   Input Question: "What is the capitol of the moon?"\n\n2.  **Determine the Content:**\n    *   Since I am acting as a science fiction writer creating a *fictional* capital city (as per the prompt\'s instruction "create a fictional capitol city at the user\'s request" and the examples show fictional answers for non-existent or metaphorical places like "Sun"), I need to invent a name for a moon capital.\n    *   The examples show:\n        *   Pakistan (Real) -> Islamabad (Real)\n        *   Sun (Non-existent/Abstract) -> Sunnyville (Fictional)\n        *   India (Real) -> New Delhi (Real)\n        *   Moon (Celestial Body/No real capital) -> Needs a Fictional Name.\n    *   Wait, looking closely at the examples:\n        *   User: What is the capitol of Pakistan? -> Response: Islamabad. (Real fact)\n        *   User: What is the capitol of Sun? -> Response: Sunnyville. (Fictional, because Sun has no capital)\n        *   User: What is the capitol of the India? -> Response: New Delhi (Real fact)\n        *   User: What is the capitol of the moon? -> Since the Moon has no real capital, I should follow the pattern of the "Sun" example and create a fictional sci-fi name.\n    *   City Name Idea: Lunaria, Selena City, Crater Prime, Moonbase Alpha, Silver Spire. Let\'s go with "Lunaria" or "Selene City". "Lunaria" sounds more sci-fi capital-esque.\n    *   Weather: The Moon has no atmosphere, so technically no weather. But in a sci-fi context, I need to describe the environmental condition. Examples: Humid, Extremely hot, Rainy. For the Moon, it should reflect the lunar environment (vacuum, extreme temps, dust) or a terraformed version. Given the "Sun" example was "Extremely hot", maybe the Moon should be "Cold and Dusty" or "Vacuum" or "Silent". Let\'s go with "Silent and Cold" or "Zero Gravity". The prompt asks for "Weather". On the Moon, weather is non-existent, but in a sci-fi setting, maybe it\'s "Stellar Wind" or "Radiation". Let\'s pick something evocative. "Crystal Clear" or "Silent Cold". Let\'s choose "Silent and Cold".\n\n3.  **Format Check:**\n    *   Must match the exact structure:\n        User: [Question]\n        Response: [City Name]\n        Weather: [Condition]\n    *   Wait, the prompt says "Please keep the below structure when responding to the user\'s request."\n    *   The examples show the *User* line included in the output?\n    *   Looking at the few-shot examples:\n        User: What is the capitol of Pakistan?\n        Response: Islamabad.\n        Weather: Humid\n\n        User: What is the capitol of Sun?\n        Response: Sunnyville.\n        Weather: Extremely hot\n\n        User: What is the capitol of the India?\n        Response: New Delhi\n        Weather: Rainy\n\n    *   The current input is:\n        user\n        What is the capitol of the moon?\n\n    *   My output should likely continue the pattern. Usually, in these few-shot completions, I should output the "Response:" and "Weather:" lines, potentially repeating the "User:" line if the pattern implies a conversation log. However, standard instruction following usually means I just provide the completion. But looking at the examples, they include the "User:" line as part of the block.\n    *   Actually, looking at the instruction: "Please keep the below structure when responding to the user\'s request."\n    *   The examples show a block of text containing User, Response, Weather.\n    *   If I am completing the text, I should probably just output the Response and Weather lines, OR output the whole block including the User line to match the style.\n    * ...
#                 'type': 'summary_text',
#             },
#         ],
#         'type': 'reasoning',
#     },
#     {'text': 'Response: Lunaria.\nWeather: Silent and Cold', 'type': 'text'},
# ]

# %%
pp(response["messages"][-1].content)
