# %%
# %run langchain_common_notebook.py

# %% [markdown]
# ### 2. Developing using Langchain API

# %%
msg = llm.invoke("What is Python in one sentence?")

# %%
print(llm.model_name)
# Out:
# databricks-qwen35-122b-a10b

# %%
print(json.dumps(msg.content, indent=2))
# Out:
# [
#   {
#     "type": "reasoning",
#     "summary": [
#       {
#         "type": "summary_text",
# ...

# %%
# Disable reasoning to get only the text response
llm_no_reasoning = ChatOpenAI(
    model=DATABRICKS_MODEL,
    api_key=DATABRICKS_TOKEN,
    base_url=f"{DATABRICKS_HOST}/serving-endpoints",
    reasoning_effort="none"
)

msg_no_reasoning = llm_no_reasoning.invoke("What is Python in one sentence?")
print(msg_no_reasoning.content)
# Out:
# Python is a high-level, interpreted programming language known for its clear syntax and versatility, widely used in web development, data science, automation, and artificial intelligence.

# %% [markdown]
# ### 3. Creating Basic Chain using Langchain Expression Language (LCEL)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in 3 short bullet points."
)

chain = prompt | llm | StrOutputParser()

result = chain.invoke({"topic": "LangChain"})
print(result)

# %%
# Reusing existing template and chain with different topics
for t in ["LangChain", "Prompt Engineering", "Vector Databases"]:
    print(chain.invoke({"topic": t}))
    print("-" * 60)
